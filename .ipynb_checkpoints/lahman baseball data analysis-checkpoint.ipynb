# %%
import pandas as pd
import numpy as np
# using data.world so no local files needed
import datadotworld as dw
# Import the baseball dataset
dataset = dw.load_dataset('natereed/lahman-baseball-data')
dataset.describe()
# Out:
# {'homepage': 'https://data.world/natereed/lahman-baseball-data',
#  'keywords': ['baseball', 'sports'],
#  'license': 'Other',
#  'name': 'natereed_lahman-baseball-data',
#  'resources': [{'format': 'csv',
#    'name': 'allstarfull',
#    'path': 'data/allstarfull.csv'},
#   {'format': 'csv', 'name': 'appearances', 'path': 'data/appearances.csv'},
#   {'format': 'csv',
#    'name': 'awardsmanagers',
#    'path': 'data/awardsmanagers.csv'},
#   {'format': 'csv', 'name': 'awardsplayers', 'path': 'data/awardsplayers.csv'},
#   {'format': 'csv',
#    'name': 'awardssharemanagers',
#    'path': 'data/awardssharemanagers.csv'},
#   {'format': 'csv',
#    'name': 'awardsshareplayers',
#    'path': 'data/awardsshareplayers.csv'},
#   {'format': 'csv', 'name': 'batting', 'path': 'data/batting.csv'},
#   {'format': 'csv', 'name': 'battingpost', 'path': 'data/battingpost.csv'},
#   {'format': 'csv',
#    'name': 'collegeplaying',
#    'path': 'data/collegeplaying.csv'},
# ...
